# %%
# notification_consumer.py
from kafka import KafkaConsumer, KafkaProducer
import os
import json
import uuid
from concurrent.futures import ThreadPoolExecutor
TOPIC_NAME = "NOTIFICATION"
KAFKA_SERVER = "kafka:29092"

# %%
consumer = KafkaConsumer(
    TOPIC_NAME,
    bootstrap_servers=[KAFKA_SERVER],
    enable_auto_commit=False,
    # to deserialize kafka.producer.object into dict
    #value_deserializer=lambda m: json.loads(m.decode('utf-8')),
)

# %%
consumer = KafkaConsumer(
    TOPIC_NAME,
    bootstrap_servers=[KAFKA_SERVER],
    auto_offset_reset='earliest',
    enable_auto_commit=False,
    # to deserialize kafka.producer.object into dict
    #value_deserializer=lambda m: json.loads(m.decode('utf-8')),
)

# %%
def sendNotification(data):
	# process steps
    print(data)
    json_data = json.loads(data)

    if(json_data['avgbpm'] >= 120):
        print("\nALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)\n")

    if(json_data['avgtemp'] >= 38):
        print("\nALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)\n")

    #if(json_data['avgpressao'] >= 13):
    #    print("\nALERTA RECEBIDO! Cheque sua pressao! (P >= 13)\n")

    #if(json_data['avgrespiracao'] >= 20):
    #    print("\nALERTA RECEBIDO! Cheque sua frequencia respiratoria! (F >= 20)\n")

    #if(json_data['avgglicemia'] >= 100):
    #    print("\nALERTA RECEBIDO! Cheque sua glicemia! (G >= 100)\n")

    #if(json_data['avgsaturacao_oxigenio'] <= 94):
    #    print("\nALERTA RECEBIDO! Cheque sua saturação do oxigenio! (S <= 94)\n")

# %%
for notification in consumer:
    
    print(notification.value)
    notification_data = notification.value
    sendNotification(notification_data)
# Out:
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-01 11:05:00","nome":"joao","avgbpm":126.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-01 11:05:00","nome":"joao","avgbpm":126.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 12:15:00","nome":"maria","avgbpm":79.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-04 12:15:00","nome":"maria","avgbpm":79.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 01:30:00","nome":"joao","avgbpm":76.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-11 01:30:00","nome":"joao","avgbpm":76.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 04:55:00","nome":"maria","avgbpm":63.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-14 04:55:00","nome":"maria","avgbpm":63.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 09:10:00","nome":"maria","avgbpm":105.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-15 09:10:00","nome":"maria","avgbpm":105.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 18:55:00","nome":"maria","avgbpm":70.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-20 18:55:00","nome":"maria","avgbpm":70.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-23 18:00:00","nome":"joao","avgbpm":87.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-23 18:00:00","nome":"joao","avgbpm":87.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-25 18:30:00","nome":"joao","avgbpm":79.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-25 18:30:00","nome":"joao","avgbpm":79.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-28 05:20:00","nome":"maria","avgbpm":69.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-28 05:20:00","nome":"maria","avgbpm":69.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-01 11:05:00","nome":"joao","avgbpm":126.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-01 11:05:00","nome":"joao","avgbpm":126.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 12:15:00","nome":"maria","avgbpm":79.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-04 12:15:00","nome":"maria","avgbpm":79.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 01:30:00","nome":"joao","avgbpm":76.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-11 01:30:00","nome":"joao","avgbpm":76.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 04:55:00","nome":"maria","avgbpm":63.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-14 04:55:00","nome":"maria","avgbpm":63.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 09:10:00","nome":"maria","avgbpm":105.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-15 09:10:00","nome":"maria","avgbpm":105.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-17 04:00:00","nome":"antonio","avgbpm":90.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-17 04:00:00","nome":"antonio","avgbpm":90.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 18:55:00","nome":"maria","avgbpm":70.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-20 18:55:00","nome":"maria","avgbpm":70.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-21 21:50:00","nome":"maria","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-21 21:50:00","nome":"maria","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-23 18:00:00","nome":"joao","avgbpm":87.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-23 18:00:00","nome":"joao","avgbpm":87.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-24 21:20:00","nome":"maria","avgbpm":120.0,"avgtemp":36.0}'
# b'{"eventTime":"2022-03-24 21:20:00","nome":"maria","avgbpm":120.0,"avgtemp":36.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-25 18:30:00","nome":"joao","avgbpm":79.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-25 18:30:00","nome":"joao","avgbpm":79.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-28 05:20:00","nome":"maria","avgbpm":69.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-28 05:20:00","nome":"maria","avgbpm":69.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-01 11:05:00","nome":"joao","avgbpm":126.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-01 11:05:00","nome":"joao","avgbpm":126.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 12:15:00","nome":"maria","avgbpm":79.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-04 12:15:00","nome":"maria","avgbpm":79.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-06 09:40:00","nome":"antonio","avgbpm":72.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-06 09:40:00","nome":"antonio","avgbpm":72.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-07 03:50:00","nome":"joao","avgbpm":40.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-07 03:50:00","nome":"joao","avgbpm":40.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-09 05:30:00","nome":"joao","avgbpm":77.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-09 05:30:00","nome":"joao","avgbpm":77.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 01:30:00","nome":"joao","avgbpm":76.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-11 01:30:00","nome":"joao","avgbpm":76.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 04:55:00","nome":"maria","avgbpm":63.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-14 04:55:00","nome":"maria","avgbpm":63.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 22:40:00","nome":"antonio","avgbpm":92.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-14 22:40:00","nome":"antonio","avgbpm":92.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 09:10:00","nome":"maria","avgbpm":105.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-15 09:10:00","nome":"maria","avgbpm":105.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-17 04:00:00","nome":"antonio","avgbpm":90.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-17 04:00:00","nome":"antonio","avgbpm":90.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 18:55:00","nome":"maria","avgbpm":70.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-20 18:55:00","nome":"maria","avgbpm":70.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-21 21:50:00","nome":"maria","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-21 21:50:00","nome":"maria","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-23 18:00:00","nome":"joao","avgbpm":87.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-23 18:00:00","nome":"joao","avgbpm":87.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-24 21:20:00","nome":"maria","avgbpm":120.0,"avgtemp":36.0}'
# b'{"eventTime":"2022-03-24 21:20:00","nome":"maria","avgbpm":120.0,"avgtemp":36.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-25 18:30:00","nome":"joao","avgbpm":79.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-25 18:30:00","nome":"joao","avgbpm":79.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-28 05:20:00","nome":"maria","avgbpm":69.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-28 05:20:00","nome":"maria","avgbpm":69.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-01 11:05:00","nome":"joao","avgbpm":126.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-01 11:05:00","nome":"joao","avgbpm":126.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-02 18:40:00","nome":"antonio","avgbpm":70.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-02 18:40:00","nome":"antonio","avgbpm":70.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 12:15:00","nome":"maria","avgbpm":79.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-04 12:15:00","nome":"maria","avgbpm":79.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-06 09:40:00","nome":"antonio","avgbpm":72.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-06 09:40:00","nome":"antonio","avgbpm":72.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-07 03:50:00","nome":"joao","avgbpm":40.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-07 03:50:00","nome":"joao","avgbpm":40.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-08 00:45:00","nome":"antonio","avgbpm":90.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-08 00:45:00","nome":"antonio","avgbpm":90.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-08 21:50:00","nome":"antonio","avgbpm":91.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-08 21:50:00","nome":"antonio","avgbpm":91.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-09 05:30:00","nome":"joao","avgbpm":77.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-09 05:30:00","nome":"joao","avgbpm":77.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 01:30:00","nome":"joao","avgbpm":76.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-11 01:30:00","nome":"joao","avgbpm":76.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 22:35:00","nome":"joao","avgbpm":101.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-11 22:35:00","nome":"joao","avgbpm":101.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-12 06:15:00","nome":"joao","avgbpm":108.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-12 06:15:00","nome":"joao","avgbpm":108.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-13 01:30:00","nome":"maria","avgbpm":85.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-13 01:30:00","nome":"maria","avgbpm":85.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 04:55:00","nome":"maria","avgbpm":63.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-14 04:55:00","nome":"maria","avgbpm":63.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 20:25:00","nome":"maria","avgbpm":68.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-14 20:25:00","nome":"maria","avgbpm":68.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 22:40:00","nome":"antonio","avgbpm":92.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-14 22:40:00","nome":"antonio","avgbpm":92.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 22:55:00","nome":"joao","avgbpm":74.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-14 22:55:00","nome":"joao","avgbpm":74.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 09:10:00","nome":"maria","avgbpm":105.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-15 09:10:00","nome":"maria","avgbpm":105.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 05:15:00","nome":"antonio","avgbpm":117.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-16 05:15:00","nome":"antonio","avgbpm":117.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-17 04:00:00","nome":"antonio","avgbpm":90.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-17 04:00:00","nome":"antonio","avgbpm":90.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-17 04:10:00","nome":"joao","avgbpm":79.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-17 04:10:00","nome":"joao","avgbpm":79.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 18:55:00","nome":"maria","avgbpm":70.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-20 18:55:00","nome":"maria","avgbpm":70.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-21 21:50:00","nome":"maria","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-21 21:50:00","nome":"maria","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-23 05:25:00","nome":"antonio","avgbpm":95.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-23 05:25:00","nome":"antonio","avgbpm":95.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-23 18:00:00","nome":"joao","avgbpm":87.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-23 18:00:00","nome":"joao","avgbpm":87.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-24 21:20:00","nome":"maria","avgbpm":120.0,"avgtemp":36.0}'
# b'{"eventTime":"2022-03-24 21:20:00","nome":"maria","avgbpm":120.0,"avgtemp":36.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-25 18:30:00","nome":"joao","avgbpm":79.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-25 18:30:00","nome":"joao","avgbpm":79.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-27 23:15:00","nome":"maria","avgbpm":76.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-27 23:15:00","nome":"maria","avgbpm":76.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-28 05:20:00","nome":"maria","avgbpm":69.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-28 05:20:00","nome":"maria","avgbpm":69.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-01 02:35:00","nome":"joao","avgbpm":110.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-01 02:35:00","nome":"joao","avgbpm":110.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-01 11:05:00","nome":"joao","avgbpm":126.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-01 11:05:00","nome":"joao","avgbpm":126.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-02 13:45:00","nome":"maria","avgbpm":92.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-02 13:45:00","nome":"maria","avgbpm":92.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-02 18:40:00","nome":"antonio","avgbpm":70.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-02 18:40:00","nome":"antonio","avgbpm":70.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
# b'{"eventTime":"2022-03-02 20:05:00","nome":"antonio","avgbpm":134.0,"avgtemp":38.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-04 06:20:00","nome":"joao","avgbpm":93.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-04 12:15:00","nome":"maria","avgbpm":79.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-04 12:15:00","nome":"maria","avgbpm":79.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-05 14:10:00","nome":"maria","avgbpm":73.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-05 14:10:00","nome":"maria","avgbpm":73.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-06 09:40:00","nome":"antonio","avgbpm":72.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-06 09:40:00","nome":"antonio","avgbpm":72.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-07 03:50:00","nome":"joao","avgbpm":40.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-07 03:50:00","nome":"joao","avgbpm":40.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-08 00:45:00","nome":"antonio","avgbpm":90.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-08 00:45:00","nome":"antonio","avgbpm":90.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-08 21:50:00","nome":"antonio","avgbpm":91.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-08 21:50:00","nome":"antonio","avgbpm":91.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-09 05:30:00","nome":"joao","avgbpm":77.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-09 05:30:00","nome":"joao","avgbpm":77.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-10 04:35:00","nome":"antonio","avgbpm":99.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 01:30:00","nome":"joao","avgbpm":76.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-11 01:30:00","nome":"joao","avgbpm":76.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 07:55:00","nome":"joao","avgbpm":129.0,"avgtemp":36.0}'
# b'{"eventTime":"2022-03-11 07:55:00","nome":"joao","avgbpm":129.0,"avgtemp":36.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-11 22:35:00","nome":"joao","avgbpm":101.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-11 22:35:00","nome":"joao","avgbpm":101.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-11 23:35:00","nome":"maria","avgbpm":124.0,"avgtemp":38.0}'
# b'{"eventTime":"2022-03-11 23:35:00","nome":"maria","avgbpm":124.0,"avgtemp":38.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-12 06:15:00","nome":"joao","avgbpm":108.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-12 06:15:00","nome":"joao","avgbpm":108.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-13 01:30:00","nome":"maria","avgbpm":85.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-13 01:30:00","nome":"maria","avgbpm":85.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 04:55:00","nome":"maria","avgbpm":63.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-14 04:55:00","nome":"maria","avgbpm":63.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 20:25:00","nome":"maria","avgbpm":68.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-14 20:25:00","nome":"maria","avgbpm":68.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 22:40:00","nome":"antonio","avgbpm":92.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-14 22:40:00","nome":"antonio","avgbpm":92.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-14 22:55:00","nome":"joao","avgbpm":74.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-14 22:55:00","nome":"joao","avgbpm":74.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 09:10:00","nome":"maria","avgbpm":105.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-15 09:10:00","nome":"maria","avgbpm":105.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 05:15:00","nome":"antonio","avgbpm":117.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-16 05:15:00","nome":"antonio","avgbpm":117.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-17 04:00:00","nome":"antonio","avgbpm":90.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-17 04:00:00","nome":"antonio","avgbpm":90.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-17 04
0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-15 17:40:00","nome":"maria","avgbpm":88.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-15 19:10:00","nome":"joao","avgbpm":123.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 04:20:00","nome":"joao","avgbpm":82.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-16 04:20:00","nome":"joao","avgbpm":82.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 05:15:00","nome":"antonio","avgbpm":117.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-16 05:15:00","nome":"antonio","avgbpm":117.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 19:40:00","nome":"maria","avgbpm":50.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-16 21:25:00","nome":"joao","avgbpm":125.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-17 04:00:00","nome":"antonio","avgbpm":90.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-17 04:00:00","nome":"antonio","avgbpm":90.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-17 04:10:00","nome":"joao","avgbpm":79.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-17 04:10:00","nome":"joao","avgbpm":79.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-17 08:45:00","nome":"joao","avgbpm":80.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-17 08:45:00","nome":"joao","avgbpm":80.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-18 07:45:00","nome":"maria","avgbpm":68.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-18 07:45:00","nome":"maria","avgbpm":68.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 01:35:00","nome":"maria","avgbpm":55.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-19 01:35:00","nome":"maria","avgbpm":55.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 05:15:00","nome":"joao","avgbpm":81.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-19 05:15:00","nome":"joao","avgbpm":81.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 06:40:00","nome":"antonio","avgbpm":74.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-19 06:40:00","nome":"antonio","avgbpm":74.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-19 07:40:00","nome":"antonio","avgbpm":81.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-19 13:35:00","nome":"joao","avgbpm":106.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-19 13:35:00","nome":"joao","avgbpm":106.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 05:55:00","nome":"antonio","avgbpm":41.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-20 05:55:00","nome":"antonio","avgbpm":41.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 06:15:00","nome":"joao","avgbpm":80.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-20 06:15:00","nome":"joao","avgbpm":80.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-20 08:00:00","nome":"joao","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-20 18:55:00","nome":"maria","avgbpm":70.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-20 18:55:00","nome":"maria","avgbpm":70.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-21 21:50:00","nome":"maria","avgbpm":109.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-21 21:50:00","nome":"maria","avgbpm":109.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-22 04:40:00","nome":"maria","avgbpm":115.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-22 08:10:00","nome":"maria","avgbpm":68.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 10:30:00","nome":"antonio","avgbpm":52.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-22 10:30:00","nome":"antonio","avgbpm":52.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-22 14:25:00","nome":"joao","avgbpm":87.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-22 14:25:00","nome":"joao","avgbpm":87.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-23 05:25:00","nome":"antonio","avgbpm":95.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-23 05:25:00","nome":"antonio","avgbpm":95.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-23 18:00:00","nome":"joao","avgbpm":87.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-23 18:00:00","nome":"joao","avgbpm":87.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-24 02:05:00","nome":"antonio","avgbpm":55.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-24 02:05:00","nome":"antonio","avgbpm":55.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-24 04:40:00","nome":"maria","avgbpm":72.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-24 04:40:00","nome":"maria","avgbpm":72.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-24 05:05:00","nome":"joao","avgbpm":114.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-24 05:05:00","nome":"joao","avgbpm":114.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-24 13:10:00","nome":"antonio","avgbpm":88.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-24 13:10:00","nome":"antonio","avgbpm":88.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-24 21:20:00","nome":"maria","avgbpm":120.0,"avgtemp":36.0}'
# b'{"eventTime":"2022-03-24 21:20:00","nome":"maria","avgbpm":120.0,"avgtemp":36.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-24 22:40:00","nome":"maria","avgbpm":121.0,"avgtemp":38.0}'
# b'{"eventTime":"2022-03-24 22:40:00","nome":"maria","avgbpm":121.0,"avgtemp":38.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-24 23:45:00","nome":"antonio","avgbpm":69.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-24 23:45:00","nome":"antonio","avgbpm":69.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-25 00:55:00","nome":"antonio","avgbpm":113.0,"avgtemp":42.0}'
# b'{"eventTime":"2022-03-25 00:55:00","nome":"antonio","avgbpm":113.0,"avgtemp":42.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-25 18:30:00","nome":"joao","avgbpm":79.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-25 18:30:00","nome":"joao","avgbpm":79.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-26 06:10:00","nome":"maria","avgbpm":68.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-26 06:10:00","nome":"maria","avgbpm":68.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
# b'{"eventTime":"2022-03-26 07:20:00","nome":"joao","avgbpm":125.0,"avgtemp":34.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
# b'{"eventTime":"2022-03-27 05:55:00","nome":"maria","avgbpm":97.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-27 05:55:00","nome":"maria","avgbpm":97.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-27 21:05:00","nome":"maria","avgbpm":130.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-27 21:05:00","nome":"maria","avgbpm":130.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque seus batimentos cardiacos! (BPM >= 120)
#
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-27 23:15:00","nome":"maria","avgbpm":76.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-27 23:15:00","nome":"maria","avgbpm":76.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-28 05:20:00","nome":"maria","avgbpm":69.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-28 05:20:00","nome":"maria","avgbpm":69.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-28 13:40:00","nome":"antonio","avgbpm":87.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-28 13:40:00","nome":"antonio","avgbpm":87.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
# b'{"eventTime":"2022-03-28 19:35:00","nome":"maria","avgbpm":105.0,"avgtemp":41.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-29 04:45:00","nome":"maria","avgbpm":87.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-29 10:05:00","nome":"antonio","avgbpm":87.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-29 10:05:00","nome":"antonio","avgbpm":87.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-30 15:40:00","nome":"maria","avgbpm":84.0,"avgtemp":40.0}'
# b'{"eventTime":"2022-03-30 15:40:00","nome":"maria","avgbpm":84.0,"avgtemp":40.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
#
# b'{"eventTime":"2022-03-30 16:45:00","nome":"joao","avgbpm":73.0,"avgtemp":39.0}'
# b'{"eventTime":"2022-03-30 16:45:00","nome":"joao","avgbpm":73.0,"avgtemp":39.0}'
#
# ALERTA RECEBIDO! Cheque sua temperatura! (T >= 38)
