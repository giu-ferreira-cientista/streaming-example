# %% [markdown]
# # Simple Notifier

# %%
# !pip install kafka-python

# %%
from kafka import KafkaConsumer
import json
from json import loads


topic_name = 'odd-topic'
kafka = 'kafka:9092'

consumer = KafkaConsumer(
     topic_name,
     bootstrap_servers=[kafka],
     auto_offset_reset='earliest',
     enable_auto_commit=True,
     value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
for message in consumer:
    message = message.value  

    json_object = json.dumps(message) 
    json_object = json.loads(json_object)
    
    print('User {} Notified!'.format(json_object["id"]))
# Out:
# User 1 Notified!
# User 1 Notified!
# User 3 Notified!
# User 5 Notified!
# User 7 Notified!
# User 9 Notified!
# User 11 Notified!
# User 1 Notified!
# User 3 Notified!
# User 1 Notified!
# User 3 Notified!
# User 5 Notified!
# User 7 Notified!
# User 9 Notified!
# User 11 Notified!
# User 13 Notified!
# User 1 Notified!
# User 1 Notified!
# User 3 Notified!
# User 5 Notified!
# User 7 Notified!
# User 9 Notified!
# User 11 Notified!
# User 1 Notified!
# User 3 Notified!
# User 5 Notified!
# User 7 Notified!
# User 9 Notified!
# User 11 Notified!
# User 13 Notified!
# User 15 Notified!
# User 17 Notified!
# User 19 Notified!
# User 21 Notified!
# User 23 Notified!
# User 25 Notified!
# User 27 Notified!
# User 29 Notified!
# User 31 Notified!
# User 33 Notified!
# User 35 Notified!
# User 37 Notified!
# User 39 Notified!
# User 41 Notified!
# User 43 Notified!
# User 45 Notified!
# User 47 Notified!
# User 49 Notified!
# User 51 Notified!
# User 53 Notified!
# User 55 Notified!
# ...

# %%
# !pip install sendgrid
# Out:
# ...
#      |████████████████████████████████| 101 kB 5.0 MB/s ta 0:00:011
# ...
#   Created wheel for starkbank-ecdsa: filename=starkbank_ecdsa-2.2.0-py3-none-any.whl size=15972 sha256=29d8902bb922536efb439095348fc0dbf47a79501a94951bc55db2cfc9df5d68
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ff/e0/b9/210b1c0209f93792f212d6e61553624523e49aac6cf284151f
# Successfully built starkbank-ecdsa
# ...

# %%
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content

# %%
my_sg = sendgrid.SendGridAPIClient(api_key = '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')

# %%
# Change to your verified sender
from_email = Email("giuferreira@gmail.com")  

# Change to your recipient
to_email = To("giuferreira@gmail.com")  

subject = "Lorem ipsum dolor sit amet"
content = Content("text/plain", "consectetur adipiscing elit")

mail = Mail(from_email, to_email, subject, content)

# Get a JSON-ready representation of the Mail object
mail_json = mail.get()

# Send an HTTP POST request to /mail/send
response = my_sg.client.mail.send.post(request_body=mail_json)

# %%
print(response.status_code, response.body, response.headers)
# Out:
# 202 b'' Server: nginx
# Date: Sat, 10 Dec 2022 16:02:37 GMT
# Content-Length: 0
# Connection: close
# X-Message-Id: mgx6gknDS1C_XgkpLMIuAw
# Access-Control-Allow-Origin: https://sendgrid.api-docs.io
# Access-Control-Allow-Methods: POST
# Access-Control-Allow-Headers: Authorization, Content-Type, On-behalf-of, x-sg-elas-acl
# Access-Control-Max-Age: 600
# X-No-CORS-Reason: https://sendgrid.com/docs/Classroom/Basics/API/cors.html
# Strict-Transport-Security: max-age=600; includeSubDomains

# %%
for message in consumer:
    message = message.value    
    print('{} added'.format(message))
# Out:
# {'id': 0, 'nome': 'simple-0'} added
# {'id': 1, 'nome': 'simple-1'} added
# {'id': 2, 'nome': 'simple-2'} added
# {'id': 3, 'nome': 'simple-3'} added
# {'id': 4, 'nome': 'simple-4'} added
# {'id': 5, 'nome': 'simple-5'} added
# {'id': 6, 'nome': 'simple-6'} added
# {'id': 7, 'nome': 'simple-7'} added
# {'id': 8, 'nome': 'simple-8'} added
# {'id': 9, 'nome': 'simple-9'} added
# {'id': 10, 'nome': 'simple-10'} added
# {'id': 11, 'nome': 'simple-11'} added
# {'id': 12, 'nome': 'simple-12'} added
# {'id': 13, 'nome': 'simple-13'} added
# {'id': 14, 'nome': 'simple-14'} added
# {'id': 15, 'nome': 'simple-15'} added
# {'id': 16, 'nome': 'simple-16'} added
# {'id': 17, 'nome': 'simple-17'} added
# {'id': 18, 'nome': 'simple-18'} added
# {'id': 19, 'nome': 'simple-19'} added
# {'id': 20, 'nome': 'simple-20'} added
# {'id': 21, 'nome': 'simple-21'} added
# {'id': 22, 'nome': 'simple-22'} added
# {'id': 23, 'nome': 'simple-23'} added
# {'id': 24, 'nome': 'simple-24'} added
# ...
